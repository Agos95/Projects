# %%
# mount Google Drive Folder
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd "/content/drive/My Drive/Colab Notebooks/DeepLearning"
# Out:
# /content/drive/My Drive/Colab Notebooks/DeepLearning

# %%
# !python train.py
# Out:
# device:  cuda
# ==================================================
#                Tuning the optimizer
# ==================================================
# 100% 36/36 [6:38:46<00:00, 657.47s/it]
# Parameters search over optimizer results:
#         lr  ...  Val_Loss
# 0  0.0100  ...  0.022443
# 0  0.0100  ...  0.022501
# 0  0.0050  ...  0.022681
# 0  0.0050  ...  0.022696
# 0  0.0050  ...  0.023907
# 0  0.0100  ...  0.024008
# 0  0.0010  ...  0.024487
# 0  0.0010  ...  0.024647
# 0  0.0010  ...  0.024993
# 0  0.0010  ...  0.025661
# 0  0.0005  ...  0.025888
# 0  0.0050  ...  0.025967
# 0  0.0100  ...  0.026368
# 0  0.0100  ...  0.027252
# 0  0.0005  ...  0.028574
# 0  0.0005  ...  0.029692
# 0  0.0500  ...  0.029941
# 0  0.0005  ...  0.030095
# 0  0.0005  ...  0.031157
# 0  0.0500  ...  0.032177
# 0  0.0500  ...  0.034001
# 0  0.0001  ...  0.043508
# 0  0.0001  ...  0.046280
# 0  0.0001  ...  0.050179
# 0  0.0001  ...  0.050890
# 0  0.0001  ...  0.053711
# 0  0.0050  ...  0.053998
# 0  0.0010  ...  0.060492
# 0  0.0100  ...  0.062497
# 0  0.0010  ...  0.062725
# 0  0.0050  ...  0.062736
# 0  0.0500  ...  0.063092
# 0  0.0005  ...  0.063158
# 0  0.0001  ...  0.065714
# 0  0.0500  ...  0.067462
# 0  0.0500  ...  0.078312
#
# [36 rows x 4 columns]
#
#
# ==================================================
#         Tuning the hidden layer dimension
# ==================================================
# 100% 10/10 [1:45:20<00:00, 633.64s/it]
#
# Parameters search over hidden layer size results:
#    esd  Test_Loss
# 0  20   0.009258
# 0  15   0.010073
# 0  25   0.010108
# 0  30   0.011145
# 0  12   0.012720
# 0   8   0.017079
# 0  10   0.018720
# 0   6   0.020458
# 0   4   0.027136
# 0   2   0.044586
